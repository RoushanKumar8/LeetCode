# %%
print("Hello Roushan!")
# Out:
# Hello Roushan!

# %% [markdown]
# ## Leetcode question no 136(Single Number)

# %%
nums = [4,1,2,1,2]
unique = 0
for num in nums:
    unique ^= num
    print(unique)
# Out:
# 4
# 5
# 7
# 6
# 4

# %%
nums = [2,2,1]
unique = 0
for num in nums:
    unique = unique ^ num
print(unique)
# Out:
# 1
