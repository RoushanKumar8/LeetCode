# %%
print("Hello Roushan!")
# Out:
# Hello Roushan!

# %% [markdown]
# ## Leetcode Question no 349(Intersection of Two Arrays).

# %% [markdown]
# ### Leetcode question no

# %%
nums1 = [1,2,2,1]
nums2 = [2,2]
set1 = set(nums1)
set2 = set(nums2)

intersaction = set1 & set2
print(list(intersaction))
# Out:
# [2]
