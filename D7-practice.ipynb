# %% [markdown]
# ### Leetcode Question no 125(Valid Palindrome)

# %%
print("Hello Roushan!")
# Out:
# Hello Roushan!

# %%
s = "A man, a plan, a canal: Panama"
left = 0
right = len(s)-1

while left < right:
    while left < right and not s[left].isalnum():
        left += 1
    while left < right and not s[right].isalnum():
        right -= 1
    
    if s[left].lower() != s[right].lower():
        print(False)
        break

    left += 1
    right -= 1

print(True)
# Out:
# True

# %% [markdown]
# ### Leetcode Question no 680(Valid Palindrome ||)

# %%
# Out:
# False
