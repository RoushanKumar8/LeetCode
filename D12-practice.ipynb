# %%
print("Hello Roushan")
# Out:
# Hello Roushan

# %% [markdown]
# ## Leetcode Question no 977(Square of a Sorted Array)

# %%
nums = [-4,-1,0,3,10]

for i,num in enumerate(nums):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
nums = [-4,-1,0,3,10]
n = len(nums)
result = []
for i, num in enumerate(nums):
    num = num**2
    result.append(num)
result.sort()
print(result)
# Out:
# [0, 1, 9, 16, 100]

# %% [markdown]
# ## Final Leetcode code

# %%
class Solution:
    def sortedSquares(self, nums):
        n = len(nums)
        result = []
        for i, num in enumerate(nums):
            num = num**2
            result.append(num)
        result.sort()
        return result
